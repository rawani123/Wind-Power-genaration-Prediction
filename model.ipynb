# %%
import numpy as np
import pandas as pd

# %%
gridData = pd.read_csv('D:\\APSHAH\\backend\\Grid_data\\final_griddata.csv')

# %%
gridData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43823 entries, 0 to 43822
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       43823 non-null  object
#  1   p1         43823 non-null  float64
#  2   p2         43823 non-null  float64
#  3   p3         43823 non-null  float64
#  4   c1         43823 non-null  float64
#  5   c2         43823 non-null  float64
#  6   c3         43823 non-null  float64
#  7   stability  43823 non-null  object
# dtypes: float64(6), object(2)
# memory usage: 2.7+ MB

# %%
gridData['date'] = pd.to_datetime(gridData['date'])
gridData.info()
gridData
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43823 entries, 0 to 43822
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       43823 non-null  datetime64[ns]
#  1   p1         43823 non-null  float64
#  2   p2         43823 non-null  float64
#  3   p3         43823 non-null  float64
#  4   c1         43823 non-null  float64
#  5   c2         43823 non-null  float64
#  6   c3         43823 non-null  float64
#  7   stability  43823 non-null  object
# dtypes: datetime64[ns](1), float64(6), object(1)
# memory usage: 2.7+ MB
#                      date        p1        p2        p3        c1        c2  \
# 0     2019-01-01 01:00:00  0.859578  0.887445  0.958034 -0.782604 -1.257395
# 1     2019-01-01 02:00:00  0.862414  0.562139  0.781760 -1.940058 -1.872742
# 2     2019-01-01 03:00:00  0.766689  0.839444  0.109853 -1.207456 -1.277210
# ...

# %%
category_mapping = {'unstable': 0, 'stable': 1}

# Use the map() function to convert categories to numerical values
gridData['stability'] = gridData['stability'].map(category_mapping)

# %%
gridData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43823 entries, 0 to 43822
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       43823 non-null  datetime64[ns]
#  1   p1         43823 non-null  float64
#  2   p2         43823 non-null  float64
#  3   p3         43823 non-null  float64
#  4   c1         43823 non-null  float64
#  5   c2         43823 non-null  float64
#  6   c3         43823 non-null  float64
#  7   stability  43823 non-null  int64
# dtypes: datetime64[ns](1), float64(6), int64(1)
# memory usage: 2.7 MB

# %%
gridData.isnull().sum()
# Out:
# date         0
# p1           0
# p2           0
# p3           0
# c1           0
# c2           0
# c3           0
# stability    0
# dtype: int64

# %%
gridData.isna().sum()
# Out:
# date         0
# p1           0
# p2           0
# p3           0
# c1           0
# c2           0
# c3           0
# stability    0
# dtype: int64

# %%
print(gridData.duplicated().any()) 
print(gridData.duplicated())
gridData
# Out:
# False
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 43818    False
# 43819    False
# 43820    False
# 43821    False
# 43822    False
# Length: 43823, dtype: bool
#                      date        p1        p2        p3        c1        c2  \
# 0     2019-01-01 01:00:00  0.859578  0.887445  0.958034 -0.782604 -1.257395
# 1     2019-01-01 02:00:00  0.862414  0.562139  0.781760 -1.940058 -1.872742
# 2     2019-01-01 03:00:00  0.766689  0.839444  0.109853 -1.207456 -1.277210
# 3     2019-01-01 04:00:00  0.976744  0.929381  0.362718 -1.027473 -1.938944
# 4     2019-01-01 05:00:00  0.455450  0.656947  0.820923 -1.125531 -1.845975
# ...                   ...       ...       ...       ...       ...       ...
# 43818 2023-12-31 19:00:00  0.257940  0.895296  0.868929 -1.954289 -0.981347
# 43819 2023-12-31 20:00:00  0.848075  0.909264  0.266201 -1.428185 -0.525543
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
print(plt.figure(figsize = (10, 4), dpi = 100)) 
sns.boxplot(x = "p1", data = gridData)
# Out:
# Figure(1000x400)
# <Axes: xlabel='p1'>

# %%
print(plt.figure(figsize = (10, 4), dpi = 100)) 
sns.boxplot(x = "p2", data = gridData)
# Out:
# Figure(1000x400)
# <Axes: xlabel='p2'>

# %%
print(plt.figure(figsize = (10, 4), dpi = 100)) 
sns.boxplot(x = "p3", data = gridData)
# Out:
# Figure(1000x400)
# <Axes: xlabel='p3'>

# %%
print(plt.figure(figsize = (10, 4), dpi = 100)) 
sns.boxplot(x = "c1", data = gridData)
# Out:
# Figure(1000x400)
# <Axes: xlabel='c1'>

# %%
print(plt.figure(figsize = (10, 4), dpi = 100)) 
sns.boxplot(x = "c2", data = gridData)
# Out:
# Figure(1000x400)
# <Axes: xlabel='c2'>

# %%
print(plt.figure(figsize = (10, 4), dpi = 100)) 
sns.boxplot(x = "c3", data = gridData)
# Out:
# Figure(1000x400)
# <Axes: xlabel='c3'>

# %%
print(plt.figure(figsize = (10, 4), dpi = 100)) 
sns.boxplot(x = "stability", data = gridData)
# Out:
# Figure(1000x400)
# <Axes: xlabel='stability'>

# %%
plt.figure(figsize = (10, 4), dpi = 100) 
color_palette = sns.color_palette("Accent_r") 
sns.set_palette(color_palette)
sns.countplot(x = "stability", data = gridData)
# Out:
# <Axes: xlabel='stability', ylabel='count'>

# %%
plt.figure(figsize = (10, 6), dpi = 100) 
color = sns.color_palette("magma")
sns.heatmap(gridData.corr(), vmax=0.9, annot=True,cmap = color)
# Out:
# C:\Users\ANIRUDDHA\AppData\Local\Temp\ipykernel_11300\4047699404.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(gridData.corr(), vmax=0.9, annot=True,cmap = color)
# <Axes: >

# %%
plt.figure(figsize=(16,8))
plt.subplot(2,2,1)
sns.distplot(gridData['c1'])
plt.subplot(2,2,2)
sns.boxplot(gridData['c1'])
# Out:
# C:\Users\ANIRUDDHA\AppData\Local\Temp\ipykernel_11300\1452521160.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(gridData['c1'])
# <Axes: ylabel='c1'>

# %%
mean_rate = gridData['p1'].mean()


# ddof is the degrees of freedom correction 
# in the calculation of the standard deviation;
# for population standard deviation ddof=0
stdev_rate = gridData['p1'].std(ddof=0)

# %%
print('Mean participation rate is {:.3f}'.format(mean_rate))
print('Standard deviation is {:.3f}'.format(stdev_rate))
# Out:
# Mean participation rate is 0.524
# Standard deviation is 0.274

# %%
gridData.describe()
# Out:
#                  p1            p2            p3            c1            c2  \
# count  43823.000000  43823.000000  43823.000000  43823.000000  43823.000000
# mean       0.524386      0.525091      0.524850     -1.250546     -1.249507
# std        0.274152      0.274024      0.274112      0.432717      0.433164
# min        0.050028      0.050028      0.050028     -1.999945     -1.999945
# 25%        0.287146      0.288137      0.287527     -1.624822     -1.625254
# 50%        0.523687      0.524937      0.524818     -1.250468     -1.249347
# 75%        0.761357      0.762186      0.762276     -0.876309     -0.873360
# max        0.999982      0.999982      0.999982     -0.500025     -0.500025
#
#                  c3     stability
# count  43823.000000  43823.000000
# mean      -1.249552      0.362527
# std        0.432663      0.480735
# min       -1.999945      0.000000
# 25%       -1.624678      0.000000
# 50%       -1.248716      0.000000
# 75%       -0.875252      1.000000
# ...

# %%
import seaborn as sns
plt.figure(figsize=(8, 6))
sns.histplot(gridData['p1'], bins=30, kde=True)
plt.title('Power 1')
plt.xlabel('power1')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x='date', y='p1', data=gridData)
plt.title('Scatterplot of Date and power 1')
plt.xlabel('Date')
plt.ylabel('Power 1')
plt.show()

# %%
powerGenaration = pd.read_csv('D:\\APSHAH\\backend\\wind_data\\final_2_data.csv')

# %%
powerGenaration.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42801 entries, 0 to 42800
# Data columns (total 5 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   DateTime                          42801 non-null  object
#  1   Air temperature | (°C)            42801 non-null  float64
#  2   Power generated by system | (MW)  42801 non-null  float64
#  3   Pressure | (atm)                  42801 non-null  float64
#  4   Wind speed | (m/s)                42801 non-null  float64
# dtypes: float64(4), object(1)
# memory usage: 1.6+ MB

# %%
powerGenaration['DateTime'] = pd.to_datetime(powerGenaration['DateTime'])

# %%
powerGenaration.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42801 entries, 0 to 42800
# Data columns (total 5 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   DateTime                          42801 non-null  datetime64[ns]
#  1   Air temperature | (°C)            42801 non-null  float64
#  2   Power generated by system | (MW)  42801 non-null  float64
#  3   Pressure | (atm)                  42801 non-null  float64
#  4   Wind speed | (m/s)                42801 non-null  float64
# dtypes: datetime64[ns](1), float64(4)
# memory usage: 1.6 MB

# %%
final_data = pd.merge(powerGenaration, gridData, left_on='DateTime', right_on='date', how='inner')

# %%
final_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 42601 entries, 0 to 42600
# Data columns (total 13 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   DateTime                          42601 non-null  datetime64[ns]
#  1   Air temperature | (°C)            42601 non-null  float64
#  2   Power generated by system | (MW)  42601 non-null  float64
#  3   Pressure | (atm)                  42601 non-null  float64
#  4   Wind speed | (m/s)                42601 non-null  float64
#  5   date                              42601 non-null  datetime64[ns]
#  6   p1                                42601 non-null  float64
#  7   p2                                42601 non-null  float64
#  8   p3                                42601 non-null  float64
#  9   c1                                42601 non-null  float64
#  10  c2                                42601 non-null  float64
# ...

# %%
final_data.shape
# Out:
# (42601, 13)

# %%
final_data.head()
# Out:
#              DateTime  Air temperature | (°C)  \
# 0 2019-01-01 01:00:00                  10.926
# 1 2019-01-01 02:00:00                   9.919
# 2 2019-01-05 07:00:00                  15.058
# 3 2019-01-05 08:00:00                  15.037
# 4 2019-01-09 13:00:00                   0.447
#
#    Power generated by system | (MW)  Pressure | (atm)  Wind speed | (m/s)  \
# 0                           33.6881          0.979103               9.014
# 1                           37.2619          0.979566               9.428
# 2                           41.2384          0.976353               9.970
# 3                           44.0998          0.975986              10.262
# 4                           53.1118          0.985490              10.917
#
#                  date        p1        p2        p3        c1        c2  \
# 0 2019-01-01 01:00:00  0.859578  0.887445  0.958034 -0.782604 -1.257395
# 1 2019-01-01 02:00:00  0.862414  0.562139  0.781760 -1.940058 -1.872742
# ...

# %%
final_data = final_data.drop(columns=['date'])

# %%
final_data.head()
# Out:
#              DateTime  Air temperature | (°C)  \
# 0 2019-01-01 01:00:00                  10.926
# 1 2019-01-01 02:00:00                   9.919
# 2 2019-01-05 07:00:00                  15.058
# 3 2019-01-05 08:00:00                  15.037
# 4 2019-01-09 13:00:00                   0.447
#
#    Power generated by system | (MW)  Pressure | (atm)  Wind speed | (m/s)  \
# 0                           33.6881          0.979103               9.014
# 1                           37.2619          0.979566               9.428
# 2                           41.2384          0.976353               9.970
# 3                           44.0998          0.975986              10.262
# 4                           53.1118          0.985490              10.917
#
#          p1        p2        p3        c1        c2        c3  stability
# 0  0.859578  0.887445  0.958034 -0.782604 -1.257395 -1.723086          0
# 1  0.862414  0.562139  0.781760 -1.940058 -1.872742 -1.255012          1
# ...

# %%
final_data.to_csv('D:\\APSHAH\\backend\\final_data.csv', index=False)

# %%
final_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 42601 entries, 0 to 42600
# Data columns (total 12 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   DateTime                          42601 non-null  datetime64[ns]
#  1   Air temperature | (°C)            42601 non-null  float64
#  2   Power generated by system | (MW)  42601 non-null  float64
#  3   Pressure | (atm)                  42601 non-null  float64
#  4   Wind speed | (m/s)                42601 non-null  float64
#  5   p1                                42601 non-null  float64
#  6   p2                                42601 non-null  float64
#  7   p3                                42601 non-null  float64
#  8   c1                                42601 non-null  float64
#  9   c2                                42601 non-null  float64
#  10  c3                                42601 non-null  float64
# ...

# %%
final_data['year'] = final_data['DateTime'].dt.year
final_data['month'] = final_data['DateTime'].dt.month
final_data['day'] = final_data['DateTime'].dt.day
final_data['hour'] = final_data['DateTime'].dt.hour
final_data['minute'] = final_data['DateTime'].dt.minute
final_data['seconds'] = final_data['DateTime'].dt.second
final_data['milliseconds'] = final_data['DateTime'].dt.microsecond // 1000

# %%
final_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 42601 entries, 0 to 42600
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Air temperature | (°C)            42601 non-null  float64
#  1   Power generated by system | (MW)  42601 non-null  float64
#  2   Pressure | (atm)                  42601 non-null  float64
#  3   Wind speed | (m/s)                42601 non-null  float64
#  4   p1                                42601 non-null  float64
#  5   p2                                42601 non-null  float64
#  6   p3                                42601 non-null  float64
#  7   c1                                42601 non-null  float64
#  8   c2                                42601 non-null  float64
#  9   c3                                42601 non-null  float64
#  10  stability                         42601 non-null  int64
# ...

# %%
final_data.head()
# Out:
#              DateTime  Air temperature | (°C)  \
# 0 2019-01-01 01:00:00                  10.926
# 1 2019-01-01 02:00:00                   9.919
# 2 2019-01-05 07:00:00                  15.058
# 3 2019-01-05 08:00:00                  15.037
# 4 2019-01-09 13:00:00                   0.447
#
#    Power generated by system | (MW)  Pressure | (atm)  Wind speed | (m/s)  \
# 0                           33.6881          0.979103               9.014
# 1                           37.2619          0.979566               9.428
# 2                           41.2384          0.976353               9.970
# 3                           44.0998          0.975986              10.262
# 4                           53.1118          0.985490              10.917
#
#          p1        p2        p3        c1        c2        c3  stability  \
# 0  0.859578  0.887445  0.958034 -0.782604 -1.257395 -1.723086          0
# 1  0.862414  0.562139  0.781760 -1.940058 -1.872742 -1.255012          1
# ...

# %%
final_data.drop(columns=['DateTime'], inplace=True)

# %%
final_data.head()
# Out:
#    Air temperature | (°C)  Power generated by system | (MW)  Pressure | (atm)  \
# 0                  10.926                           33.6881          0.979103
# 1                   9.919                           37.2619          0.979566
# 2                  15.058                           41.2384          0.976353
# 3                  15.037                           44.0998          0.975986
# 4                   0.447                           53.1118          0.985490
#
#    Wind speed | (m/s)        p1        p2        p3        c1        c2  \
# 0               9.014  0.859578  0.887445  0.958034 -0.782604 -1.257395
# 1               9.428  0.862414  0.562139  0.781760 -1.940058 -1.872742
# 2               9.970  0.218556  0.950419  0.686399 -1.068023 -1.068014
# 3              10.262  0.192119  0.546717  0.270880 -1.286522 -0.873916
# 4              10.917  0.786407  0.513784  0.169981 -1.388577 -1.458133
#
# ...

# %%
# import pandas as pd
# from sklearn.model_selection import train_test_split
# from sklearn.ensemble import RandomForestRegressor

# # Load the data


# # Specify features (X) and target (y)
# X = final_data[['Air temperature | (°C)', 'Pressure | (atm)', 'Wind speed | (m/s)', 'p1', 'p2', 'p3', 'c1', 'c2', 'c3', 'stability', 'year', 'month', 'day', 'hour', 'minute', 'seconds', 'milliseconds']]
# y = final_data['Power generated by system | (MW)']

# # Split the data into training and testing sets
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=50)

# # Train the model
# model = RandomForestRegressor(random_state=42)
# model.fit(X_train, y_train)

# # Create new data for prediction
# new_data = pd.DataFrame({
#     'Air temperature | (°C)': [10.926],
#     'Pressure | (atm)': [33.6881],
#     'Wind speed | (m/s)': [9.014],
#     'stability': [0],  # Adjust with your actual value
#     'year': [2024],  # Adjust with your actual value
#     'month': [3],     # Adjust with your actual value
#     'day': [17],       # Adjust with your actual value
#     'hour': [1],      # Adjust with your actual value
#     'minute': [0],    # Adjust with your actual value
#     'seconds': [0],   # Adjust with your actual value
#     'milliseconds': [0]  # Adjust with your actual value
# })

# # Make predictions
# predicted_power = model.predict(new_data)

# print("Predicted power generated Random Forest:", predicted_power)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor

# Load the data


# Specify features (X) and target (y)
X = final_data[['Air temperature | (°C)', 'Pressure | (atm)', 'Wind speed | (m/s)', 'p1', 'p2', 'p3', 'c1', 'c2', 'c3', 'stability', 'year', 'month', 'day', 'hour', 'minute', 'seconds', 'milliseconds']]
y = final_data['Power generated by system | (MW)']

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=50)

# Train the model
model = RandomForestRegressor(random_state=42)
model.fit(X_train, y_train)

# Create new data for prediction
new_data = pd.DataFrame({
    'Air temperature | (°C)': [6.609],
    'Pressure | (atm)': [0.988077],
    'Wind speed | (m/s)': [10.868],
    'p1': [0.859578],  # Adjust with your actual value
    'p2': [0.887445],  # Adjust with your actual value
    'p3': [0.958034],  # Adjust with your actual value
    'c1': [-0.782604],  # Adjust with your actual value
    'c2': [-1.257395],  # Adjust with your actual value
    'c3': [-1.723086],  # Adjust with your actual value
    'stability': [0],  # Adjust with your actual value
    'year': [2024],  # Adjust with your actual value
    'month': [1],     # Adjust with your actual value
    'day': [1],       # Adjust with your actual value
    'hour': [0],      # Adjust with your actual value
    'minute': [0],    # Adjust with your actual value
    'seconds': [0],   # Adjust with your actual value
    'milliseconds': [0]  # Adjust with your actual value
})

# Make predictions
predicted_power = model.predict(new_data)

print("Predicted power generated Random Forest:", predicted_power)
# Out:
# Predicted power generated Random Forest: [52.98964]

# %%
import pandas as pd
from sklearn.ensemble import RandomForestRegressor

# Load the data (Replace "your_data.csv" with the actual file path)

# Specify features (X) and target (y)
X = final_data[['Air temperature | (°C)', 'Pressure | (atm)', 'Wind speed | (m/s)', 'p1', 'p2', 'p3', 'c1', 'c2', 'c3', 'stability', 'year', 'month', 'day', 'hour', 'minute', 'seconds', 'milliseconds']]
y = final_data['Power generated by system | (MW)']

# Train the model
model = RandomForestRegressor(random_state=42)
model.fit(X, y)

# Create new data for the next 3 months
new_data_3_months = pd.DataFrame({
    'Air temperature | (°C)': [6.609] * 3,  # Assuming same value for all 3 months
    'Pressure | (atm)': [0.988077] * 3,    # Assuming same value for all 3 months
    'Wind speed | (m/s)': [10.868] * 3,    # Assuming same value for all 3 months
    'p1': [0.859578] * 3,  # Assuming same value for all 3 months
    'p2': [0.887445] * 3,  # Assuming same value for all 3 months
    'p3': [0.958034] * 3,  # Assuming same value for all 3 months
    'c1': [-0.782604] * 3,  # Assuming same value for all 3 months
    'c2': [-1.257395] * 3,  # Assuming same value for all 3 months
    'c3': [-1.723086] * 3,  # Assuming same value for all 3 months
    'stability': [0] * 3,    # Assuming same value for all 3 months
    'year': [2024] * 3,      # Assuming same value for all 3 months
    'month': [4, 5, 6],      # Months for the next 3 months
    'day': [1] * 3,          # Assuming same value for all 3 months
    'hour': [0] * 3,         # Assuming same value for all 3 months
    'minute': [0] * 3,       # Assuming same value for all 3 months
    'seconds': [0] * 3,      # Assuming same value for all 3 months
    'milliseconds': [0] * 3  # Assuming same value for all 3 months
})

# Make predictions for the next 3 months
predicted_power_3_months = model.predict(new_data_3_months)

print("Predicted power generated for the next 3 months using RandomForestRegressor model:")
print(predicted_power_3_months)
# Out:
# Predicted power generated for the next 3 months using RandomForestRegressor model:
# [53.107706 53.106526 53.106526]

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor

# Load the data


# Specify features (X) and target (y)
X = final_data[['Air temperature | (°C)', 'Pressure | (atm)', 'Wind speed | (m/s)', 'p1', 'p2', 'p3', 'c1', 'c2', 'c3', 'stability', 'year', 'month', 'day', 'hour', 'minute', 'seconds', 'milliseconds']]
y = final_data['Power generated by system | (MW)']

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=50)

# Train the model
model = RandomForestRegressor(random_state=42)
model.fit(X_train, y_train)

# Create new data for prediction
new_data = pd.DataFrame({
    'Air temperature | (°C)': [6.609],
    'Pressure | (atm)': [0.988077],
    'Wind speed | (m/s)': [10.868],
    'p1': [0.859578],  # Adjust with your actual value
    'p2': [0.887445],  # Adjust with your actual value
    'p3': [0.958034],  # Adjust with your actual value
    'c1': [-0.782604],  # Adjust with your actual value
    'c2': [-1.257395],  # Adjust with your actual value
    'c3': [-1.723086],  # Adjust with your actual value
    'stability': [0],  # Adjust with your actual value
    'year': [2024],  # Adjust with your actual value
    'month': [1],     # Adjust with your actual value
    'day': [1],       # Adjust with your actual value
    'hour': [0],      # Adjust with your actual value
    'minute': [0],    # Adjust with your actual value
    'seconds': [0],   # Adjust with your actual value
    'milliseconds': [0]  # Adjust with your actual value
})

# Make predictions
predicted_power = model.predict(new_data)

print("Predicted power generated Random Forest:", predicted_power)


# Step 1: Calculate the total power generated
total_power_generated = predicted_power  # Assume total power generated is 1000 MW (adjust according to your actual data)

# Step 2: Distribute the power to each node based on the specified percentages
node1_power = total_power_generated * 0.20
node2_power = total_power_generated * 0.45
node3_power = total_power_generated * 0.35

# Step 3: Create a DataFrame to store the distributed power for each node
power_distribution_data = pd.DataFrame({
    'Node': ['Node 1', 'Node 2', 'Node 3'],
    'Power Generated (MW)': [node1_power, node2_power, node3_power]
})

# Print the power distribution data
print("Power Distribution to Different Nodes:")
print(power_distribution_data)
# Out:
# Predicted power generated Random Forest: [52.98964]
# Power Distribution to Different Nodes:
#      Node  Power Generated (MW)
# 0  Node 1  [10.597927999999998]
# 1  Node 2  [23.845337999999995]
# 2  Node 3  [18.546373999999993]

# %%
df=pd.read_csv('D:\\APSHAH\\backend\\\Grid_data\\final_griddata.csv')

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df['year'] = df['date'].dt.year
df['month'] = df['date'].dt.month
df['day'] = df['date'].dt.day
df['hour'] = df['date'].dt.hour
df['minute'] = df['date'].dt.minute
df['seconds'] = df['date'].dt.second
df['milliseconds'] = df['date'].dt.microsecond // 1000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43823 entries, 0 to 43822
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          43823 non-null  datetime64[ns]
#  1   p1            43823 non-null  float64
#  2   p2            43823 non-null  float64
#  3   p3            43823 non-null  float64
#  4   c1            43823 non-null  float64
#  5   c2            43823 non-null  float64
#  6   c3            43823 non-null  float64
#  7   stability     43823 non-null  object
#  8   year          43823 non-null  int64
#  9   month         43823 non-null  int64
#  10  day           43823 non-null  int64
#  11  hour          43823 non-null  int64
#  12  minute        43823 non-null  int64
#  13  seconds       43823 non-null  int64
#  14  milliseconds  43823 non-null  int64
# dtypes: datetime64[ns](1), float64(6), int64(7), object(1)
# memory usage: 5.0+ MB

# %%
df.to_csv('D:\\APSHAH\\backend\\final_griddata.csv', index=False)
